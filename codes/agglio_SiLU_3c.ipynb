# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from agglio_lib_silu import *

# %%
#-------------------------------Data Generation section---------------------------#
n = 1000
d = 50
w_radius = 10
wAst = np.random.randn(d,1)
X = getData(0, 1, n, d)/np.sqrt(d)
w0 =w_radius*np.random.randn(d,1)/np.sqrt(d)
ipAst = np.matmul(X, wAst)
y = SiLU(ipAst)

# %%
#-----------AGGLIO-GD-------------#
params={}
params['algo']='AG_GD'
params['w0']=w0
params['wAst']=wAst
objVals_agd,distVals_agd,time_agd = cross_validate(X,y,params,cross_validation=True)
# Out:
# The best parameters are {'B_init': 0.01, 'B_step': 1.01, 'alpha': 1.3666666666666667} with a score of -0.00

# %%
#-----------AGGLIO-SGD-------------#
params={}
params['algo']='AG_SGD'
params['w0']=w0
params['wAst']=wAst
objVals_agsgd,distVals_agsgd,time_agsgd = cross_validate(X,y,params,cross_validation=True)
# Out:
# The best parameters are {'B_init': 0.001, 'B_step': 1.01, 'alpha': 0.1} with a score of -0.00

# %%
#-----------AGGLIO-SVRG-------------#
params={}
params['algo']='AG_SVRG'
params['w0']=w0
params['wAst']=wAst
objVals_agsvrg,distVals_agsvrg,time_agsvrg = cross_validate(X,y,params,cross_validation=True)
# Out:
# The best parameters are {'B_init': 0.1, 'B_step': 2.0, 'alpha': 1.0} with a score of -0.02

# %%
fig = plt.figure()
plt.semilogy(time_agd, distVals_agd, label='AGGLIO-GD', color='#1b9e77', linewidth=3)
plt.semilogy(time_agsgd, distVals_agsgd, label='AGGLIO-SGD',color='#5e3c99', linewidth=3)
plt.legend()
plt.ylabel("$||w^t-w^*||_2$",fontsize=12)
plt.xlabel("Time",fontsize=12)
plt.grid()
# plt.xscale('log')
plt.title(r'n=1000, d=50, SiLU activation')
plt.show()

# %%
fig = plt.figure()
plt.semilogy(np.linspace(1,len(time_agd),num=len(time_agd)), distVals_agd, label='AGGLIO-GD', color='#1b9e77', linewidth=3)
plt.semilogy(np.linspace(1,len(time_agsgd),num=len(time_agsgd)), distVals_agsgd, label='AGGLIO-SGD',color='#5e3c99', linewidth=3)
plt.legend()
plt.ylabel("$||w^t-w^*||_2$",fontsize=12)
plt.xlabel("Iterations",fontsize=12)
plt.grid()
# plt.xscale('log')
plt.title(r'n=1000, d=50, SiLU activation')
plt.show()
